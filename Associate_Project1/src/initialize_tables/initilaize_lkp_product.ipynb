# %%
# %sql
use catalog associate_assignment;
create schema if not exists look_up_tables;

# %%
# %sql
drop table associate_assignment.look_up_tables.product

# %%
# %sql

create table if not exists associate_assignment.look_up_tables.product(
    product_id string,
    product_name string,
    unit_price DECIMAL(10,2)
);

insert into associate_assignment.look_up_tables.product values
('P001', 'Laptop', 65000.00),
('P002', 'Phone', 25000.00),
('P003', 'Tablet', 18000.00),
('P004', 'Monitor', 12000.00),
('P005', 'Camera', 35000.00),
('P006', 'Keyboard', 1500.00),
('P007', 'Mouse', 700.00),
('P008', 'Headset', 2500.00);
