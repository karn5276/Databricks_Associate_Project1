-- %%
CREATE TABLE associate_assignment.default.fact_main_order (
    order_id STRING,
    customer_id STRING,
    product_id STRING,
    quantity INT,
    price DOUBLE,
    order_date DATE,
    total_amount DOUBLE,
    _rescued_data STRING,
    ingestion_timestamp TIMESTAMP,
    source_file STRING
)
USING DELTA
